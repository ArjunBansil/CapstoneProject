# %% [markdown]
# ## Segmenting and Clustering Neighborhoods in Toronto

# %% [markdown]
# By Arjun Bansil

# %%
import wikipedia 
import requests
from bs4 import BeautifulSoup
import time
import numpy as np
import pandas as pd

# %%
website_url = requests.get("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M").text
soup = BeautifulSoup(website_url,'lxml')

# %%
table = soup.find('table',{'class':'wikitable sortable'})

# %%
rows = table.findAll('tr')
parsed_table_data = []
for row in rows:
    children = row.findChildren(recursive=False)
    row_text = []
    for child in children:
        clean_text = child.text
        clean_text = clean_text.split('&#91;')[0]
        clean_text = clean_text.split('&#160;')[-1]
        clean_text = clean_text.strip()
        row_text.append(clean_text)
        parsed_table_data.append(row_text)

# %%
predf = parsed_table_data
predf.remove(predf[0])
predf.remove(predf[1])
predf.remove(predf[2])

# %%
df = pd.DataFrame(predf)
df.columns = ["PostalCode", "Borough","Neighborhood"]
df.drop(df[df.Borough == "Not assigned"].index,inplace=True)
df
# Out:
#     PostalCode           Borough              Neighborhood
# 0     Postcode           Borough             Neighbourhood
# 6          M3A        North York                 Parkwoods
# 7          M3A        North York                 Parkwoods
# 8          M3A        North York                 Parkwoods
# 9          M4A        North York          Victoria Village
# 10         M4A        North York          Victoria Village
# 11         M4A        North York          Victoria Village
# 12         M5A  Downtown Toronto              Harbourfront
# 13         M5A  Downtown Toronto              Harbourfront
# 14         M5A  Downtown Toronto              Harbourfront
# 15         M5A  Downtown Toronto               Regent Park
# 16         M5A  Downtown Toronto               Regent Park
# 17         M5A  Downtown Toronto               Regent Park
# 18         M6A        North York          Lawrence Heights
# 19         M6A        North York          Lawrence Heights
# 20         M6A        North York          Lawrence Heights
# 21         M6A        North York            Lawrence Manor
# 22         M6A        North York            Lawrence Manor
# 23         M6A        North York            Lawrence Manor
# 24         M7A      Queen's Park              Not assigned
# 25         M7A      Queen's Park              Not assigned
# 26         M7A      Queen's Park              Not assigned
# 30         M9A         Etobicoke          Islington Avenue
# 31         M9A         Etobicoke          Islington Avenue
# 32         M9A         Etobicoke          Islington Avenue
# 33         M1B       Scarborough                     Rouge
# 34         M1B       Scarborough                     Rouge
# 35         M1B       Scarborough                     Rouge
# 36         M1B       Scarborough                   Malvern
# 37         M1B       Scarborough                   Malvern
# ..         ...               ...                       ...
# 810        M8Y         Etobicoke                 Mimico NE
# 811        M8Y         Etobicoke                 Mimico NE
# 812        M8Y         Etobicoke                 Mimico NE
# 813        M8Y         Etobicoke            Old Mill South
# 814        M8Y         Etobicoke            Old Mill South
# 815        M8Y         Etobicoke            Old Mill South
# 816        M8Y         Etobicoke        The Queensway East
# 817        M8Y         Etobicoke        The Queensway East
# 818        M8Y         Etobicoke        The Queensway East
# 819        M8Y         Etobicoke     Royal York South East
# 820        M8Y         Etobicoke     Royal York South East
# 821        M8Y         Etobicoke     Royal York South East
# 822        M8Y         Etobicoke                  Sunnylea
# 823        M8Y         Etobicoke                  Sunnylea
# 824        M8Y         Etobicoke                  Sunnylea
# 849        M8Z         Etobicoke  Kingsway Park South West
# 850        M8Z         Etobicoke  Kingsway Park South West
# 851        M8Z         Etobicoke  Kingsway Park South West
# 852        M8Z         Etobicoke                 Mimico NW
# 853        M8Z         Etobicoke                 Mimico NW
# 854        M8Z         Etobicoke                 Mimico NW
# 855        M8Z         Etobicoke        The Queensway West
# 856        M8Z         Etobicoke        The Queensway West
# 857        M8Z         Etobicoke        The Queensway West
# 858        M8Z         Etobicoke     Royal York South West
# 859        M8Z         Etobicoke     Royal York South West
# 860        M8Z         Etobicoke     Royal York South West
# 861        M8Z         Etobicoke            South of Bloor
# 862        M8Z         Etobicoke            South of Bloor
# 863        M8Z         Etobicoke            South of Bloor
#
# [637 rows x 3 columns]

# %%
for index, row in df.iterrows():
    if row["Neighborhood"] == "Not assigned":
        row["Neighborhood"] = row["Borough"]
df,
# Out:
#     PostalCode           Borough              Neighborhood
# 0     Postcode           Borough             Neighbourhood
# 6          M3A        North York                 Parkwoods
# 7          M3A        North York                 Parkwoods
# 8          M3A        North York                 Parkwoods
# 9          M4A        North York          Victoria Village
# 10         M4A        North York          Victoria Village
# 11         M4A        North York          Victoria Village
# 12         M5A  Downtown Toronto              Harbourfront
# 13         M5A  Downtown Toronto              Harbourfront
# 14         M5A  Downtown Toronto              Harbourfront
# 15         M5A  Downtown Toronto               Regent Park
# 16         M5A  Downtown Toronto               Regent Park
# 17         M5A  Downtown Toronto               Regent Park
# 18         M6A        North York          Lawrence Heights
# 19         M6A        North York          Lawrence Heights
# 20         M6A        North York          Lawrence Heights
# 21         M6A        North York            Lawrence Manor
# 22         M6A        North York            Lawrence Manor
# 23         M6A        North York            Lawrence Manor
# 24         M7A      Queen's Park              Queen's Park
# 25         M7A      Queen's Park              Queen's Park
# 26         M7A      Queen's Park              Queen's Park
# 30         M9A         Etobicoke          Islington Avenue
# 31         M9A         Etobicoke          Islington Avenue
# 32         M9A         Etobicoke          Islington Avenue
# 33         M1B       Scarborough                     Rouge
# 34         M1B       Scarborough                     Rouge
# 35         M1B       Scarborough                     Rouge
# 36         M1B       Scarborough                   Malvern
# 37         M1B       Scarborough                   Malvern
# ..         ...               ...                       ...
# 810        M8Y         Etobicoke                 Mimico NE
# 811        M8Y         Etobicoke                 Mimico NE
# 812        M8Y         Etobicoke                 Mimico NE
# 813        M8Y         Etobicoke            Old Mill South
# 814        M8Y         Etobicoke            Old Mill South
# 815        M8Y         Etobicoke            Old Mill South
# 816        M8Y         Etobicoke        The Queensway East
# 817        M8Y         Etobicoke        The Queensway East
# 818        M8Y         Etobicoke        The Queensway East
# 819        M8Y         Etobicoke     Royal York South East
# 820        M8Y         Etobicoke     Royal York South East
# 821        M8Y         Etobicoke     Royal York South East
# 822        M8Y         Etobicoke                  Sunnylea
# 823        M8Y         Etobicoke                  Sunnylea
# 824        M8Y         Etobicoke                  Sunnylea
# 849        M8Z         Etobicoke  Kingsway Park South West
# 850        M8Z         Etobicoke  Kingsway Park South West
# 851        M8Z         Etobicoke  Kingsway Park South West
# 852        M8Z         Etobicoke                 Mimico NW
# 853        M8Z         Etobicoke                 Mimico NW
# 854        M8Z         Etobicoke                 Mimico NW
# 855        M8Z         Etobicoke        The Queensway West
# 856        M8Z         Etobicoke        The Queensway West
# 857        M8Z         Etobicoke        The Queensway West
# 858        M8Z         Etobicoke     Royal York South West
# 859        M8Z         Etobicoke     Royal York South West
# 860        M8Z         Etobicoke     Royal York South West
# 861        M8Z         Etobicoke            South of Bloor
# 862        M8Z         Etobicoke            South of Bloor
# 863        M8Z         Etobicoke            South of Bloor
#
# [637 rows x 3 columns]
