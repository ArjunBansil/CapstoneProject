# %% [markdown]
# ## Segmenting and Clustering Neighborhoods in Toronto

# %% [markdown]
# By Arjun Bansil

# %%
import wikipedia 
import requests
from bs4 import BeautifulSoup
import time
import numpy as np
import pandas as pd

# %%
website_url = requests.get("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M").text
soup = BeautifulSoup(website_url,'lxml')

# %%
table = soup.find('table',{'class':'wikitable sortable'})

# %%
rows = table.findAll('tr')
parsed_table_data = []
for row in rows:
    children = row.findChildren(recursive=False)
    row_text = []
    for child in children:
        clean_text = child.text
        clean_text = clean_text.split('&#91;')[0]
        clean_text = clean_text.split('&#160;')[-1]
        clean_text = clean_text.strip()
        row_text.append(clean_text)
        parsed_table_data.append(row_text)

# %%
predf = parsed_table_data
predf.remove(predf[0])
predf.remove(predf[1])
predf.remove(predf[2])

# %%
df = pd.DataFrame(predf)
df.columns = ["PostalCode", "Borough","Neighborhood"]
df.drop(df[df.Borough == "Not assigned"].index,inplace=True)
df
# Out:
#     PostalCode           Borough              Neighborhood
# 4          M3A        North York                 Parkwoods
# 5          M3A        North York                 Parkwoods
# 6          M3A        North York                 Parkwoods
# 7          M4A        North York          Victoria Village
# 8          M4A        North York          Victoria Village
# 9          M4A        North York          Victoria Village
# 10         M5A  Downtown Toronto              Harbourfront
# 11         M5A  Downtown Toronto              Harbourfront
# 12         M5A  Downtown Toronto              Harbourfront
# 13         M5A  Downtown Toronto               Regent Park
# 14         M5A  Downtown Toronto               Regent Park
# 15         M5A  Downtown Toronto               Regent Park
# 16         M6A        North York          Lawrence Heights
# 17         M6A        North York          Lawrence Heights
# 18         M6A        North York          Lawrence Heights
# 19         M6A        North York            Lawrence Manor
# 20         M6A        North York            Lawrence Manor
# 21         M6A        North York            Lawrence Manor
# 22         M7A      Queen's Park              Not assigned
# 23         M7A      Queen's Park              Not assigned
# 24         M7A      Queen's Park              Not assigned
# 28         M9A         Etobicoke          Islington Avenue
# 29         M9A         Etobicoke          Islington Avenue
# 30         M9A         Etobicoke          Islington Avenue
# 31         M1B       Scarborough                     Rouge
# 32         M1B       Scarborough                     Rouge
# 33         M1B       Scarborough                     Rouge
# 34         M1B       Scarborough                   Malvern
# 35         M1B       Scarborough                   Malvern
# 36         M1B       Scarborough                   Malvern
# ..         ...               ...                       ...
# 808        M8Y         Etobicoke                 Mimico NE
# 809        M8Y         Etobicoke                 Mimico NE
# 810        M8Y         Etobicoke                 Mimico NE
# 811        M8Y         Etobicoke            Old Mill South
# 812        M8Y         Etobicoke            Old Mill South
# 813        M8Y         Etobicoke            Old Mill South
# 814        M8Y         Etobicoke        The Queensway East
# 815        M8Y         Etobicoke        The Queensway East
# 816        M8Y         Etobicoke        The Queensway East
# 817        M8Y         Etobicoke     Royal York South East
# 818        M8Y         Etobicoke     Royal York South East
# 819        M8Y         Etobicoke     Royal York South East
# 820        M8Y         Etobicoke                  Sunnylea
# 821        M8Y         Etobicoke                  Sunnylea
# 822        M8Y         Etobicoke                  Sunnylea
# 847        M8Z         Etobicoke  Kingsway Park South West
# 848        M8Z         Etobicoke  Kingsway Park South West
# 849        M8Z         Etobicoke  Kingsway Park South West
# 850        M8Z         Etobicoke                 Mimico NW
# 851        M8Z         Etobicoke                 Mimico NW
# 852        M8Z         Etobicoke                 Mimico NW
# 853        M8Z         Etobicoke        The Queensway West
# 854        M8Z         Etobicoke        The Queensway West
# 855        M8Z         Etobicoke        The Queensway West
# 856        M8Z         Etobicoke     Royal York South West
# 857        M8Z         Etobicoke     Royal York South West
# 858        M8Z         Etobicoke     Royal York South West
# 859        M8Z         Etobicoke            South of Bloor
# 860        M8Z         Etobicoke            South of Bloor
# 861        M8Z         Etobicoke            South of Bloor
#
# [636 rows x 3 columns]

# %%
for index, row in df.iterrows():
